# %%
import numpy as np
import scipy as sp
import pandas as pd
import gensim
# Out:
# C:\Users\Sakshi Garg\Anaconda3\lib\site-packages\gensim\utils.py:862: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
data=pd.read_csv(r'E:\new\mymovies.csv', engine='python')
data1=pd.read_csv(r'E:\new\mybooks.csv', engine='python')

# %%
lst=list(data.keywords)
from pprint import pprint
pprint(lst)
from gensim import corpora, models, similarities
import nltk as n
#tok_corp=[n.word_tokenize(sakshi.decode('utf-8')) for sakshi in lst]
#pprint(tok_corp)

#pprint(model)
# Out:
# ["['game', 'board', 'giant', 'home', 'childrens', 'insect', 'based', 'book', "
#  "'recluse', 'disappearance', 'new']",
#  "['friend', 'fishing', 'old', 'men', 'best', 'duringcreditsstinger']",
#  "['single', 'novel', 'interracial', 'chick', 'based', 'relationship', "
#  "'flick', 'divorce', 'mother']",
#  "['contraception', 'daughter', 'midlife', 'baby', 'pregnancy', 'aging', "
#  "'crisis', 'gynecologist', 'relationship', 'confidence', 'mother']",
#  "['job', 'excon', 'fight', 'epic', 'shooting', 'film', 'betrayal', "
#  "'criminal', 'mastermind', 'honor', 'heist', 'gun', 'neonoir', 'chase', "
#  "'detective', 'cat', 'one', 'bank', 'robbery', 'obsession', 'movie', 'last', "
#  "'thief', 'crime', 'cult', 'gang', 'mouse', 'suspense', 'murder', 'loner', "
#  "'money']",
#  "['millionaire', 'chauffeur', 'long', 'fusion', 'relationship', 'brother', "
#  "'island', 'paris']",
#  "['']",
#  "['vice', 'terrorist', 'president', 'explosive', 'hostage']",
# ...

# %%
import string
translator = str.maketrans('', '', string.punctuation)
slist=[]
for i in range(0,len(lst)):
    lst[i]=lst[i].translate(translator)
    lst[i]=lst[i].split()
    slist.append(lst[i])

# %%
#model=gensim.models.Word2Vec(slist)
model = gensim.models.KeyedVectors.load_word2vec_format('E:/new/googlevectors.bin/GoogleNews-vectors-negative300.bin', binary = True)

# %%
print(model)

# %%
distance = model.wmdistance(['cat','dog'], ['water','sunlight'])

# %%
print(distance)
# Out:
# 4.205771124811172

# %%
model.most_similar(positive=['woman', 'king'], negative=['man'], topn=1)
