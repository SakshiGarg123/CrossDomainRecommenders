# %%
import pandas as pd

# %%
df1=pd.read_csv(r"new_genre_correlation_matrix.csv",engine='python')
df1.head()
# Out:
#   Unnamed: 0  photography  crossover  adventure  bangsian  chick  tale  \
# 0    fantasy           10         80         75        85     77    65
# 1    romance           70         50         55        60     50    80
# 2  adventure           20         90         95        55     22    70
# 3    odyssey           60         70         65        20     25    55
# 4     comedy           10         12         15        30     15    30
#
#    journal  graphic  fictional    ...     sorcery  mashup  low  speculative  \
# 0       10       12         84    ...          50      12   12           30
# 1        8       20         37    ...          10      25   30            3
# 2       12       10         45    ...          12      50    7           35
# 3       21       35         40    ...           5       8   33           10
# 4       25       50         28    ...           8      10    5            2
#
#    book  true  play  postmodernism  sciences  parallel
# ...
